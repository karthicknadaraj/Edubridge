# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READ THE DATA

# %%
d=pd.read_csv(r'C:\Users\hp\Desktop\Data Analytics\only_road_accidents_data_month2.csv')

# %% [markdown]
# # VIEW THE DATA

# %%
d
# Out:
#           STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %% [markdown]
# # TO PRINT COLUMN NAMES

# %%
d.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY',
#        'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER',
#        'DECEMBER', 'TOTAL'],
#       dtype='object')

# %% [markdown]
# # TO KNOW HOW MANY ROWS AND COLUMNS

# %%
d.shape
# Out:
# (490, 15)

# %% [markdown]
# # TO PRINT THE SIZE

# %%
d.size
# Out:
# 7350

# %% [markdown]
# # TO CHECK THE DATA TYPE OF ATTRIBUTES

# %%
d.dtypes
# Out:
# STATE/UT     object
# YEAR          int64
# JANUARY       int64
# FEBRUARY      int64
# MARCH         int64
# APRIL         int64
# MAY           int64
# JUNE          int64
# JULY          int64
# AUGUST        int64
# SEPTEMBER     int64
# OCTOBER       int64
# NOVEMBER      int64
# DECEMBER      int64
# TOTAL         int64
# dtype: object

# %% [markdown]
# # TO CHECK NULL VALUES

# %%
d.isnull()
# Out:
#      STATE/UT   YEAR  JANUARY  FEBRUARY  MARCH  APRIL    MAY   JUNE   JULY  \
# 0       False  False    False     False  False  False  False  False  False
# 1       False  False    False     False  False  False  False  False  False
# 2       False  False    False     False  False  False  False  False  False
# 3       False  False    False     False  False  False  False  False  False
# 4       False  False    False     False  False  False  False  False  False
# ..        ...    ...      ...       ...    ...    ...    ...    ...    ...
# 485     False  False    False     False  False  False  False  False  False
# 486     False  False    False     False  False  False  False  False  False
# 487     False  False    False     False  False  False  False  False  False
# 488     False  False    False     False  False  False  False  False  False
# 489     False  False    False     False  False  False  False  False  False
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# ...

# %% [markdown]
# # SUM OF NULL VALUES

# %%
d.isnull().sum()
# Out:
# STATE/UT     0
# YEAR         0
# JANUARY      0
# FEBRUARY     0
# MARCH        0
# APRIL        0
# MAY          0
# JUNE         0
# JULY         0
# AUGUST       0
# SEPTEMBER    0
# OCTOBER      0
# NOVEMBER     0
# DECEMBER     0
# TOTAL        0
# dtype: int64

# %% [markdown]
# # TO PRINT THE INDEX

# %%
d.index
# Out:
# RangeIndex(start=0, stop=490, step=1)

# %% [markdown]
# # TO PRINT THE NUMBER OF DIMENSIONS

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# # TO CHECK WHETHER THE DATA IS EMPTY OR NOT

# %%
d.empty
# Out:
# False

# %% [markdown]
# # PRINT THE DATASET INFO

# %%
d.info
# Out:
# <bound method DataFrame.info of           STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %% [markdown]
# # TO PRINT THE STATISTICAL INFORMATION

# %%
d.describe
# Out:
# <bound method NDFrame.describe of           STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %%
d.describe(include='all')
# Out:
#          STATE/UT         YEAR      JANUARY     FEBRUARY        MARCH  \
# count         490   490.000000   490.000000   490.000000   490.000000
# unique         37          NaN          NaN          NaN          NaN
# top     Karnataka          NaN          NaN          NaN          NaN
# freq           14          NaN          NaN          NaN          NaN
# mean          NaN  2007.500000   985.140816   937.289796   992.124490
# std           NaN     4.035249  1403.961467  1326.928970  1403.445117
# min           NaN  2001.000000     0.000000     0.000000     0.000000
# 25%           NaN  2004.000000    31.000000    30.000000    32.250000
# 50%           NaN  2007.500000   329.500000   348.500000   369.000000
# 75%           NaN  2011.000000  1513.500000  1394.250000  1381.000000
# max           NaN  2014.000000  9062.000000  8705.000000  9205.000000
#
#               APRIL          MAY         JUNE         JULY       AUGUST  \
# ...

# %% [markdown]
# # CHECK THE DUPLICATED VALUE

# %%
d.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# Length: 490, dtype: bool

# %% [markdown]
# # SUM OF DUPLICATED VALUES

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Number of Unique values in dataset

# %%
d.nunique()
# Out:
# STATE/UT      37
# YEAR          14
# JANUARY      357
# FEBRUARY     356
# MARCH        349
# APRIL        349
# MAY          359
# JUNE         358
# JULY         355
# AUGUST       353
# SEPTEMBER    345
# OCTOBER      358
# NOVEMBER     350
# DECEMBER     350
# TOTAL        454
# dtype: int64

# %% [markdown]
# # COUNT THE STATES OF DATA GIVEN

# %%
d['STATE/UT'].value_counts()
# Out:
# Karnataka            14
# Kerala               14
# Meghalaya            14
# Sikkim               14
# Gujarat              14
# Maharashtra          14
# Rajasthan            14
# Puducherry           14
# Goa                  14
# Himachal Pradesh     14
# Chandigarh           14
# Uttar Pradesh        14
# Chhattisgarh         14
# Jharkhand            14
# West Bengal          14
# Uttarakhand          14
# Madhya Pradesh       14
# Punjab               14
# Daman & Diu          14
# A & N Islands        14
# Assam                14
# Andhra Pradesh       14
# Bihar                14
# Nagaland             14
# Arunachal Pradesh    14
# Jammu & Kashmir      14
# Tamil Nadu           14
# Odisha               14
# Tripura              14
# Haryana              14
# Lakshadweep          14
# Manipur              14
# Mizoram              14
# Delhi (Ut)           13
# D & N Haveli         13
# Delhi Ut              1
# D&N Haveli            1
# Name: STATE/UT, dtype: int64

# %% [markdown]
# # TOP FIVE RECORDS

# %%
d.head()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL  MAY  JUNE  JULY  \
# 0  A & N Islands  2001        8        23     15     15   14    19    14
# 1  A & N Islands  2002       12        10     14     16   10     7    16
# 2  A & N Islands  2003       19        13     15     13   13    12     8
# 3  A & N Islands  2004       21        14     22     17   13    18    16
# 4  A & N Islands  2005       19        21     22     17   13    19    21
#
#    AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0      19          7       12        13        22    181
# 1      11         23       21        11        17    168
# 2      16         17       25        14        15    180
# 3      19         16       20        15        24    215
# 4      14         15       19        10        16    206

# %% [markdown]
# # BOTTOM FIVE RECORDS

# %%
d.tail()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 485  West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486  West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487  West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488  West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489  West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 485    1190       1128     1227      1251      1252  14725
# 486    1074       1112     1214      1161      1270  14468
# 487    1204       1112     1251      1179      1371  15608
# 488    1208       1228     1299      1335      1332  16549
# 489    1356       1391     1395      1415      1394  17105

# %% [markdown]
# # MINIMUM VALUE OF RECORDS

# %%
d.min()
# Out:
# STATE/UT     A & N Islands
# YEAR                  2001
# JANUARY                  0
# FEBRUARY                 0
# MARCH                    0
# APRIL                    0
# MAY                      0
# JUNE                     0
# JULY                     0
# AUGUST                   0
# SEPTEMBER                0
# OCTOBER                  0
# NOVEMBER                 0
# DECEMBER                 0
# TOTAL                    0
# dtype: object

# %% [markdown]
# # MAXIMUM VALUE OF RECORD

# %%
d.max()
# Out:
# STATE/UT     West Bengal
# YEAR                2014
# JANUARY             9062
# FEBRUARY            8705
# MARCH               9205
# APRIL               9006
# MAY                 9330
# JUNE                5915
# JULY                5719
# AUGUST              5936
# SEPTEMBER           5777
# OCTOBER             5516
# NOVEMBER            5367
# DECEMBER            5562
# TOTAL              75480
# dtype: object

# %% [markdown]
# # STATE/UT vs TOTAL

# %%
plt.figure(figsize=(14,7))
d.groupby('STATE/UT')['TOTAL'].sum().plot.bar(color=['red','orange','green'])
plt.xlabel('STATE/UT')
plt.ylabel('TOTAL')
plt.title('STATE/UT vs TOTAL ACCIDENTS HAPPENS')
plt.grid(True)
plt.show()

# %% [markdown]
# # YEAR VS TOTAL

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='YEAR',y='TOTAL',data=d)
plt.title('YEAR VS TOTAL RANGE OF ACCIDENTS HAPPEN')
plt.show()

# %% [markdown]
# # QUERY TO EXTRACT THE STATE = WB

# %%
d_wb=d.loc[(d['STATE/UT']=='West Bengal')]
d_wb
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 476  West Bengal  2001      897       908    948   1039   952   972   915
# 477  West Bengal  2002      894       932    942   1041   911   854   915
# 478  West Bengal  2003      916       930   1084    975   909   980  1054
# 479  West Bengal  2004     1044      1001   1197   1085  1086  1043   964
# 480  West Bengal  2005     1036      1061   1084   1035  1096  1049   998
# 481  West Bengal  2006     1112      1093   1187   1053  1124  1153  1011
# 482  West Bengal  2007     1134      1051   1275   1240  1157  1269  1176
# 483  West Bengal  2008      974       919   1097   1013  1069  1000   875
# 484  West Bengal  2009     1231      1150   1183   1101  1158  1180  1162
# 485  West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486  West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487  West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# ...

# %% [markdown]
# # CALCULATING THE TOTAL RECORD  OF WB

# %%
a=d_wb.loc[:,'TOTAL']
s1=np.sum(a)
s1
# Out:
# 189375

# %% [markdown]
# # YEAR VS TOTAL WISE OF WB

# %%
plt.figure(figsize=(12,6))
plt.bar(d_wb['YEAR'],d_wb['TOTAL'],color='r')
plt.xlabel('YEAR')
plt.ylabel("TOTAL")
plt.title('YEAR VS TOTAL WISE OF WEST BENGAL')
plt.show()

# %% [markdown]
# # QUERY TO EXTRACT THE STATE OF TAMIL NADU

# %%
d_tn=d.loc[(d['STATE/UT']=='Tamil Nadu')]
d_tn
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 420  Tamil Nadu  2001     4174      4264   4724   4442  4465  4453  4370
# 421  Tamil Nadu  2002     4326      4300   4703   4788  4935  4609  4434
# 422  Tamil Nadu  2003     4278      4114   4341   3928  4244  4378  4177
# 423  Tamil Nadu  2004     4160      4252   4457   4421  4540  4495  4373
# 424  Tamil Nadu  2005     9062      8705   9205   9006  9330  5691  4235
# 425  Tamil Nadu  2006     4435      4322   4781   4808  5082  5029  4365
# 426  Tamil Nadu  2007     4855      4527   4911   5348  5414  4978  4841
# 427  Tamil Nadu  2008     4962      4626   5018   5465  5532  5087  4947
# 428  Tamil Nadu  2009     4950      4802   4927   4956  5406  5241  4975
# 429  Tamil Nadu  2010     5498      5199   5727   5663  6027  5393  5221
# 430  Tamil Nadu  2011     5522      5228   5821   5461  6018  5879  5706
# 431  Tamil Nadu  2012     5868      5646   5813   5819  5896  5646  5688
# ...

# %% [markdown]
# # CALCULATING THE TOTAL RECORD OF TN

# %%
a=d_tn.loc[:,'TOTAL']
s2=np.sum(a)
s2
# Out:
# 852073

# %% [markdown]
# # YEAR VS TOTAL OF TN

# %%
sns.lineplot(x='YEAR',y='TOTAL',data=d_tn)
plt.show()

# %%
d.sort_values('TOTAL',ascending=False)
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 424   Tamil Nadu  2005     9062      8705   9205   9006  9330  5691  4235
# 431   Tamil Nadu  2012     5868      5646   5813   5819  5896  5646  5688
# 433   Tamil Nadu  2014     5658      5293   5824   5303  5711  5915  5719
# 432   Tamil Nadu  2013     5881      5337   5741   5599  5914  5593  5311
# 430   Tamil Nadu  2011     5522      5228   5821   5461  6018  5879  5706
# ..           ...   ...      ...       ...    ...    ...   ...   ...   ...
# 259  Lakshadweep  2008        0         0      0      0     0     0     0
# 261  Lakshadweep  2010        0         0      0      0     0     0     0
# 262  Lakshadweep  2011        0         0      0      0     0     0     0
# 264  Lakshadweep  2013        0         0      0      0     0     0     0
# 263  Lakshadweep  2012        0         0      0      0     0     0     0
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# ...

# %% [markdown]
# # QUERY TO EXTRACT THE STATE OF MAHARASHTRA

# %%
d_mra=d.loc[(d['STATE/UT']=='Maharashtra')]
d_mra
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 280  Maharashtra  2001     3162      3015   3272   3332  3671  3179  2781
# 281  Maharashtra  2002     3424      3087   3506   3538  3970  3273  3036
# 282  Maharashtra  2003     3699      3373   3234   3430  3998  3584  3421
# 283  Maharashtra  2004     3928      3713   3677   3714  4289  3811  3430
# 284  Maharashtra  2005     4078      3694   3832   3877  4637  4126  3564
# 285  Maharashtra  2006     4062      3741   4129   4271  4881  4194  3705
# 286  Maharashtra  2007     4572      4318   4481   4795  5206  4400  3839
# 287  Maharashtra  2008     4376      4260   4479   4839  4726  4096  3738
# 288  Maharashtra  2009     4126      4024   4199   4373  4691  4097  3531
# 289  Maharashtra  2010     4383      4036   4314   4401  4861  4393  3925
# 290  Maharashtra  2011     4332      4052   4155   3928  4675  3976  3674
# 291  Maharashtra  2012     4110      3760   3896   4031  4071  3865  3539
# ...

# %% [markdown]
# # CALCULATING THE TOTAL ACCIDENT CASES OF MAHARASHTRA

# %%
b=d_mra.loc[:,'TOTAL']
s3=np.sum(b)
s3
# Out:
# 641614

# %% [markdown]
# # YEAR vs TOTAL OF MAHARASHTRA

# %%
plt.figure(figsize=(12,6))
plt.bar(d_mra['YEAR'],d_mra['TOTAL'],color='g')
plt.xlabel("YEAR")
plt.ylabel("TOTAL")
plt.show()

# %% [markdown]
# # KDEPLOT

# %%
sns.kdeplot(d['TOTAL'],color='yellow',shade=True)
plt.show()

# %% [markdown]
# # PAIRPLOT

# %%
sns.pairplot(d)
plt.show()

# %% [markdown]
# # SWARMPLOT

# %%
sns.swarmplot(d['JANUARY'])
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.swarmplot(x='STATE/UT',y='TOTAL',hue='YEAR',data=d)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CORRELATION OF DATA

# %%
d.corr()
# Out:
#                YEAR   JANUARY  FEBRUARY     MARCH     APRIL       MAY  \
# YEAR       1.000000  0.080923  0.075772  0.075740  0.067419  0.070923
# JANUARY    0.080923  1.000000  0.998683  0.997407  0.996307  0.995364
# FEBRUARY   0.075772  0.998683  1.000000  0.998301  0.997042  0.995428
# MARCH      0.075740  0.997407  0.998301  1.000000  0.997362  0.995848
# APRIL      0.067419  0.996307  0.997042  0.997362  1.000000  0.996324
# MAY        0.070923  0.995364  0.995428  0.995848  0.996324  1.000000
# JUNE       0.078314  0.989834  0.990376  0.990938  0.990623  0.992680
# JULY       0.074701  0.984711  0.985001  0.985740  0.985258  0.985114
# AUGUST     0.068334  0.981690  0.982170  0.982813  0.982605  0.980966
# SEPTEMBER  0.064217  0.984518  0.984566  0.985156  0.984666  0.983899
# OCTOBER    0.068863  0.984389  0.983981  0.983430  0.984533  0.985062
# NOVEMBER   0.073025  0.982566  0.981555  0.980949  0.981446  0.983514
# ...

# %% [markdown]
# # HEATMAP

# %%
sns.heatmap(d.corr(),center=0,cmap='RdBu',annot=True,fmt='.1f')
plt.show()

# %% [markdown]
# # DISTPLOT

# %%
sns.distplot(d.TOTAL)
plt.show()

# %%
sns.distplot(d.TOTAL,hist=False)
plt.show()

# %% [markdown]
# # DISPLOT

# %%
sns.displot(d.TOTAL,color='g')
sns.set_style('whitegrid')
plt.show()

# %% [markdown]
# # CONCLUSION:

# %% [markdown]
# # In West Bengal has 18937 Maximum total Road Accident cases are happened.

# %% [markdown]
# # In 2014 has the Maximum Accident cases in West Bengal.

# %% [markdown]
# # In 2008 has the Minimum Accident cases in West Bengal.

# %% [markdown]
# # As per the State/UT vs Total, Tamil Nadu has the highest Road accident cases.

# %% [markdown]
# # In Tamil Nadu 852073 Road Accident cases happened.

# %% [markdown]
# # In 2005 has the Maximum Road Accident cases in TN.

# %% [markdown]
# # In 2008 has the Minimum Road Accident cases in TN

# %% [markdown]
# # Maharashtra is the second Road Accident cases happened from 2002 to 2014

# %% [markdown]
# # Total cases= 641614 in Maharashtra

# %% [markdown]
# # In 2007 has the Max Road Accident cases in Maharashtra.

# %% [markdown]
# # In 2001 has the Min Road Accident cases in Maharashtra.
