# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # READ THE DATA

# %%
data=pd.read_csv(r'C:\Users\hp\Downloads\only_road_accidents_data_month2.csv')

# %% [markdown]
# # VIEW THE DATA

# %%
data
# Out:
#           STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %% [markdown]
# # TO PRINT COLUMNS NAMES

# %%
data.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY',
#        'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER',
#        'DECEMBER', 'TOTAL'],
#       dtype='object')

# %% [markdown]
# # TO CHECK HOW MANY ROWS AND COLUMNS

# %%
data.shape
# Out:
# (490, 15)

# %% [markdown]
# # TO CHECK THE SIZE

# %%
data.size
# Out:
# 7350

# %% [markdown]
# # TO CHECK THE DATATYPE OF ATTRIBUTES

# %%
data.dtypes
# Out:
# STATE/UT     object
# YEAR          int64
# JANUARY       int64
# FEBRUARY      int64
# MARCH         int64
# APRIL         int64
# MAY           int64
# JUNE          int64
# JULY          int64
# AUGUST        int64
# SEPTEMBER     int64
# OCTOBER       int64
# NOVEMBER      int64
# DECEMBER      int64
# TOTAL         int64
# dtype: object

# %% [markdown]
# # TO CHECK NULL VALUES

# %%
data.isnull()
# Out:
#      STATE/UT   YEAR  JANUARY  FEBRUARY  MARCH  APRIL    MAY   JUNE   JULY  \
# 0       False  False    False     False  False  False  False  False  False
# 1       False  False    False     False  False  False  False  False  False
# 2       False  False    False     False  False  False  False  False  False
# 3       False  False    False     False  False  False  False  False  False
# 4       False  False    False     False  False  False  False  False  False
# ..        ...    ...      ...       ...    ...    ...    ...    ...    ...
# 485     False  False    False     False  False  False  False  False  False
# 486     False  False    False     False  False  False  False  False  False
# 487     False  False    False     False  False  False  False  False  False
# 488     False  False    False     False  False  False  False  False  False
# 489     False  False    False     False  False  False  False  False  False
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# ...

# %% [markdown]
# # SUM OF NULL VALUES

# %%
data.isnull().sum()
# Out:
# STATE/UT     0
# YEAR         0
# JANUARY      0
# FEBRUARY     0
# MARCH        0
# APRIL        0
# MAY          0
# JUNE         0
# JULY         0
# AUGUST       0
# SEPTEMBER    0
# OCTOBER      0
# NOVEMBER     0
# DECEMBER     0
# TOTAL        0
# dtype: int64

# %% [markdown]
# # TO PRINT THE INDEX

# %%
data.index
# Out:
# RangeIndex(start=0, stop=490, step=1)

# %% [markdown]
# # TO PRINT THE NUMBER OF DIMENSIONS

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# # TO CHECK WHETHER THE DATA IS EMPTY OR NOT

# %%
data.empty
# Out:
# False

# %% [markdown]
# # PRINT THE DATASET INFO

# %%
data.info
# Out:
# <bound method DataFrame.info of           STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %% [markdown]
# # TO PRINT THE STATISTICAL INFORMATION

# %%
data.describe()
# Out:
#               YEAR      JANUARY     FEBRUARY        MARCH        APRIL  \
# count   490.000000   490.000000   490.000000   490.000000   490.000000
# mean   2007.500000   985.140816   937.289796   992.124490   978.904082
# std       4.035249  1403.961467  1326.928970  1403.445117  1397.371515
# min    2001.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2004.000000    31.000000    30.000000    32.250000    25.250000
# 50%    2007.500000   329.500000   348.500000   369.000000   350.000000
# 75%    2011.000000  1513.500000  1394.250000  1381.000000  1356.250000
# max    2014.000000  9062.000000  8705.000000  9205.000000  9006.000000
#
#                MAY         JUNE         JULY       AUGUST    SEPTEMBER  \
# count   490.000000   490.000000   490.000000   490.000000   490.000000
# mean   1064.414286   966.477551   898.495918   894.593878   888.371429
# std    1508.166230  1345.067531  1245.805847  1263.668002  1250.579984
# ...

# %%
data.describe(include='all')
# Out:
#                STATE/UT         YEAR      JANUARY     FEBRUARY        MARCH  \
# count               490   490.000000   490.000000   490.000000   490.000000
# unique               37          NaN          NaN          NaN          NaN
# top     Jammu & Kashmir          NaN          NaN          NaN          NaN
# freq                 14          NaN          NaN          NaN          NaN
# mean                NaN  2007.500000   985.140816   937.289796   992.124490
# std                 NaN     4.035249  1403.961467  1326.928970  1403.445117
# min                 NaN  2001.000000     0.000000     0.000000     0.000000
# 25%                 NaN  2004.000000    31.000000    30.000000    32.250000
# 50%                 NaN  2007.500000   329.500000   348.500000   369.000000
# 75%                 NaN  2011.000000  1513.500000  1394.250000  1381.000000
# max                 NaN  2014.000000  9062.000000  8705.000000  9205.000000
#
# ...

# %% [markdown]
# # CHECK THE DUPLICATED VALUE

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# Length: 490, dtype: bool

# %% [markdown]
# # SUM OF DUPLICATED VALUES

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Number of Unique values in dataset

# %%
data.nunique()
# Out:
# STATE/UT      37
# YEAR          14
# JANUARY      357
# FEBRUARY     356
# MARCH        349
# APRIL        349
# MAY          359
# JUNE         358
# JULY         355
# AUGUST       353
# SEPTEMBER    345
# OCTOBER      358
# NOVEMBER     350
# DECEMBER     350
# TOTAL        454
# dtype: int64

# %% [markdown]
# # PRINT UNIQUE YEAR IN DATASET

# %%
data.YEAR.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014], dtype=int64)

# %% [markdown]
# # PRINT TOP 5 RECORDS

# %%
data.head()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL  MAY  JUNE  JULY  \
# 0  A & N Islands  2001        8        23     15     15   14    19    14
# 1  A & N Islands  2002       12        10     14     16   10     7    16
# 2  A & N Islands  2003       19        13     15     13   13    12     8
# 3  A & N Islands  2004       21        14     22     17   13    18    16
# 4  A & N Islands  2005       19        21     22     17   13    19    21
#
#    AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 0      19          7       12        13        22    181
# 1      11         23       21        11        17    168
# 2      16         17       25        14        15    180
# 3      19         16       20        15        24    215
# 4      14         15       19        10        16    206

# %% [markdown]
# # PRINT BOTTOM 5 RECORDS

# %%
data.tail()
# Out:
#         STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 485  West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486  West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487  West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488  West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489  West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 485    1190       1128     1227      1251      1252  14725
# 486    1074       1112     1214      1161      1270  14468
# 487    1204       1112     1251      1179      1371  15608
# 488    1208       1228     1299      1335      1332  16549
# 489    1356       1391     1395      1415      1394  17105

# %% [markdown]
# # CHECK THE CORRELATION

# %%
data.corr()
# Out:
#                YEAR   JANUARY  FEBRUARY     MARCH     APRIL       MAY  \
# YEAR       1.000000  0.080923  0.075772  0.075740  0.067419  0.070923
# JANUARY    0.080923  1.000000  0.998683  0.997407  0.996307  0.995364
# FEBRUARY   0.075772  0.998683  1.000000  0.998301  0.997042  0.995428
# MARCH      0.075740  0.997407  0.998301  1.000000  0.997362  0.995848
# APRIL      0.067419  0.996307  0.997042  0.997362  1.000000  0.996324
# MAY        0.070923  0.995364  0.995428  0.995848  0.996324  1.000000
# JUNE       0.078314  0.989834  0.990376  0.990938  0.990623  0.992680
# JULY       0.074701  0.984711  0.985001  0.985740  0.985258  0.985114
# AUGUST     0.068334  0.981690  0.982170  0.982813  0.982605  0.980966
# SEPTEMBER  0.064217  0.984518  0.984566  0.985156  0.984666  0.983899
# OCTOBER    0.068863  0.984389  0.983981  0.983430  0.984533  0.985062
# NOVEMBER   0.073025  0.982566  0.981555  0.980949  0.981446  0.983514
# ...

# %% [markdown]
# # TO PRINT THE RECORD OF TAMIL NADU

# %%
data_Tamil_Nadu=data.loc[(data['STATE/UT']=='Tamil Nadu')]
data_Tamil_Nadu
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 420  Tamil Nadu  2001     4174      4264   4724   4442  4465  4453  4370
# 421  Tamil Nadu  2002     4326      4300   4703   4788  4935  4609  4434
# 422  Tamil Nadu  2003     4278      4114   4341   3928  4244  4378  4177
# 423  Tamil Nadu  2004     4160      4252   4457   4421  4540  4495  4373
# 424  Tamil Nadu  2005     9062      8705   9205   9006  9330  5691  4235
# 425  Tamil Nadu  2006     4435      4322   4781   4808  5082  5029  4365
# 426  Tamil Nadu  2007     4855      4527   4911   5348  5414  4978  4841
# 427  Tamil Nadu  2008     4962      4626   5018   5465  5532  5087  4947
# 428  Tamil Nadu  2009     4950      4802   4927   4956  5406  5241  4975
# 429  Tamil Nadu  2010     5498      5199   5727   5663  6027  5393  5221
# 430  Tamil Nadu  2011     5522      5228   5821   5461  6018  5879  5706
# 431  Tamil Nadu  2012     5868      5646   5813   5819  5896  5646  5688
# ...

# %% [markdown]
# # FIRST FIVE RECORDS OF TN

# %%
a=data_Tamil_Nadu.head()
a
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 420  Tamil Nadu  2001     4174      4264   4724   4442  4465  4453  4370
# 421  Tamil Nadu  2002     4326      4300   4703   4788  4935  4609  4434
# 422  Tamil Nadu  2003     4278      4114   4341   3928  4244  4378  4177
# 423  Tamil Nadu  2004     4160      4252   4457   4421  4540  4495  4373
# 424  Tamil Nadu  2005     9062      8705   9205   9006  9330  5691  4235
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 420    4437       4378     3985      4261      4025  51978
# 421    4523       4500     4273      3883      4229  53503
# 422    4337       4555     4397      3973      4303  51025
# 423    4696       4506     4282      4136      4190  52508
# 424    4158       4450     4082      3601      3955  75480

# %% [markdown]
# # LAST FIVE RECORDS OF TN

# %%
b=data_Tamil_Nadu.tail()
b
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 429  Tamil Nadu  2010     5498      5199   5727   5663  6027  5393  5221
# 430  Tamil Nadu  2011     5522      5228   5821   5461  6018  5879  5706
# 431  Tamil Nadu  2012     5868      5646   5813   5819  5896  5646  5688
# 432  Tamil Nadu  2013     5881      5337   5741   5599  5914  5593  5311
# 433  Tamil Nadu  2014     5658      5293   5824   5303  5711  5915  5719
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 429    5367       5349     5426      5179      4947  64996
# 430    5162       5688     5107      4937      5344  65873
# 431    5815       5283     5444      5367      5472  67757
# 432    5470       5597     5313      5268      5214  66238
# 433    5936       5777     5516      5036      5562  67250

# %% [markdown]
# # CALCULATING THE TOTAL RECORD OF 2001 TO 2005

# %%
c=a.loc[:,'TOTAL']
s1=np.sum(c)
s1
# Out:
# 284494

# %% [markdown]
# # CALCULATING THE TOTAL RECORD OF 2006 TO 2009

# %%
e=data_Tamil_Nadu[5:9]
e
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 425  Tamil Nadu  2006     4435      4322   4781   4808  5082  5029  4365
# 426  Tamil Nadu  2007     4855      4527   4911   5348  5414  4978  4841
# 427  Tamil Nadu  2008     4962      4626   5018   5465  5532  5087  4947
# 428  Tamil Nadu  2009     4950      4802   4927   4956  5406  5241  4975
#
#      AUGUST  SEPTEMBER  OCTOBER  NOVEMBER  DECEMBER  TOTAL
# 425    4891       4575     4320      4007      4530  55145
# 426    5320       4850     4758      4730      4585  59117
# 427    5436       4956     4862      4833      4685  60409
# 428    5227       5332     5288      4723      4967  60794

# %%
f=e.loc[:,"TOTAL"]
s3=np.sum(f)
s3
# Out:
# 235465

# %% [markdown]
# # CALCULATING THE TOTAL RECORD OF 2010 TO 2014

# %%
d=b.loc[:,'TOTAL']
s2=np.sum(d)
s2
# Out:
# 332114

# %% [markdown]
# # PARTICULAR COLUMN OF STATE/UT AND MARCH

# %%
d1=data.copy()
d1=d1.pivot_table("MARCH",columns='STATE/UT',aggfunc='sum')
d1
# Out:
# STATE/UT  A & N Islands  Andhra Pradesh  Arunachal Pradesh  Assam  Bihar  \
# MARCH               248           47732                295   5623   8538
#
# STATE/UT  Chandigarh  Chhattisgarh  D & N Haveli  D&N Haveli  Daman & Diu  \
# MARCH            549         10157           113           7           54
#
# STATE/UT  ...  Odisha  Puducherry  Punjab  Rajasthan  Sikkim  Tamil Nadu  \
# MARCH     ...   10439        1911    3855      27498     256       75993
#
# STATE/UT  Tripura  Uttar Pradesh  Uttarakhand  West Bengal
# MARCH         931          23888         1503        16964
#
# [1 rows x 37 columns]

# %% [markdown]
# # RENAME A COLUMN

# %%
data.rename(columns={'STATE/UT':'STATE_UT'},inplace=True)

# %%
data
# Out:
#           STATE_UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 0    A & N Islands  2001        8        23     15     15    14    19    14
# 1    A & N Islands  2002       12        10     14     16    10     7    16
# 2    A & N Islands  2003       19        13     15     13    13    12     8
# 3    A & N Islands  2004       21        14     22     17    13    18    16
# 4    A & N Islands  2005       19        21     22     17    13    19    21
# ..             ...   ...      ...       ...    ...    ...   ...   ...   ...
# 485    West Bengal  2010     1245      1150   1349   1246  1172  1284  1231
# 486    West Bengal  2011     1350      1179   1314   1148  1220  1241  1185
# 487    West Bengal  2012     1346      1383   1357   1270  1352  1434  1349
# 488    West Bengal  2013     1564      1382   1474   1392  1629  1391  1315
# 489    West Bengal  2014     1516      1398   1473   1385  1527  1439  1416
#
# ...

# %% [markdown]
# # DATA VISUALISATION

# %% [markdown]
# # PLOT A GRAPH B/W STATES/UT AND TOTAL

# %%
plt.figure(figsize=(16,8))
plt.title('STATE/UT VS TOTAL OF ROAD ACCIDENTS',fontsize=15)
plt.bar(data['STATE_UT'],data['TOTAL'],color='r')
plt.xlabel('STATE/UT',fontsize=15)
plt.xticks(rotation='vertical')
plt.ylabel('TOTAL',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# # YEAR VS TOTAL IN TAMIL NADU

# %%
plt.figure(figsize=(8,7))
x=(data_Tamil_Nadu['YEAR'])
y=(data_Tamil_Nadu['TOTAL'])
plt.plot(x,y)
plt.show()

# %%
data_Tamil_Nadu
# Out:
#        STATE/UT  YEAR  JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE  JULY  \
# 420  Tamil Nadu  2001     4174      4264   4724   4442  4465  4453  4370
# 421  Tamil Nadu  2002     4326      4300   4703   4788  4935  4609  4434
# 422  Tamil Nadu  2003     4278      4114   4341   3928  4244  4378  4177
# 423  Tamil Nadu  2004     4160      4252   4457   4421  4540  4495  4373
# 424  Tamil Nadu  2005     9062      8705   9205   9006  9330  5691  4235
# 425  Tamil Nadu  2006     4435      4322   4781   4808  5082  5029  4365
# 426  Tamil Nadu  2007     4855      4527   4911   5348  5414  4978  4841
# 427  Tamil Nadu  2008     4962      4626   5018   5465  5532  5087  4947
# 428  Tamil Nadu  2009     4950      4802   4927   4956  5406  5241  4975
# 429  Tamil Nadu  2010     5498      5199   5727   5663  6027  5393  5221
# 430  Tamil Nadu  2011     5522      5228   5821   5461  6018  5879  5706
# 431  Tamil Nadu  2012     5868      5646   5813   5819  5896  5646  5688
# ...

# %%
first_six_months=z.iloc[:,[1,2,3,4,5,6]]

# %%
first_six_months
# Out:
#      JANUARY  FEBRUARY  MARCH  APRIL   MAY  JUNE
# 420     4174      4264   4724   4442  4465  4453
# 421     4326      4300   4703   4788  4935  4609
# 422     4278      4114   4341   3928  4244  4378
# 423     4160      4252   4457   4421  4540  4495
# 424     9062      8705   9205   9006  9330  5691
# 425     4435      4322   4781   4808  5082  5029
# 426     4855      4527   4911   5348  5414  4978
# 427     4962      4626   5018   5465  5532  5087
# 428     4950      4802   4927   4956  5406  5241
# 429     5498      5199   5727   5663  6027  5393
# 430     5522      5228   5821   5461  6018  5879
# 431     5868      5646   5813   5819  5896  5646
# 432     5881      5337   5741   5599  5914  5593
# 433     5658      5293   5824   5303  5711  5915

# %% [markdown]
# # KDEPLOT

# %%
sns.kdeplot(data_Tamil_Nadu['TOTAL'])
plt.show()

# %%
sns.kdeplot(data_Tamil_Nadu['JANUARY'],color='g',shade=True)
plt.show()

# %% [markdown]
# # PAIRPLOT

# %%
type(data_Tamil_Nadu)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(data_Tamil_Nadu)
plt.show()

# %%
sns.pairplot(data_Tamil_Nadu,diag_kind='kde')
plt.show()

# %% [markdown]
# # SWARM PLOT

# %%
plt.figure(figsize=(16,8))
sns.swarmplot(x='YEAR',y='MARCH',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.xticks(rotation='vertical')
sns.swarmplot(x='STATE/UT',y='TOTAL',hue='YEAR',data=data)
plt.show()

# %% [markdown]
# # HEATMAP

# %%
data_Tamil_Nadu.corr()
# Out:
#                YEAR   JANUARY  FEBRUARY     MARCH     APRIL       MAY  \
# YEAR       1.000000  0.320734  0.232104  0.239817  0.219297  0.275885
# JANUARY    0.320734  1.000000  0.991989  0.988840  0.970780  0.981518
# FEBRUARY   0.232104  0.991989  1.000000  0.993167  0.970831  0.976804
# MARCH      0.239817  0.988840  0.993167  1.000000  0.972319  0.981561
# APRIL      0.219297  0.970780  0.970831  0.972319  1.000000  0.990924
# MAY        0.275885  0.981518  0.976804  0.981561  0.990924  1.000000
# JUNE       0.857403  0.688806  0.629967  0.652308  0.616002  0.673121
# JULY       0.916502  0.164877  0.091371  0.109265  0.081862  0.128483
# AUGUST     0.886744 -0.011883 -0.095800 -0.091677 -0.055167 -0.037162
# SEPTEMBER  0.943879  0.176692  0.090099  0.108787  0.058185  0.136059
# OCTOBER    0.928308  0.118067  0.032969  0.028107  0.019553  0.076452
# NOVEMBER   0.853821 -0.002618 -0.086627 -0.081303 -0.066555 -0.043767
# ...

# %%
sns.heatmap(data_Tamil_Nadu.corr())
plt.show()

# %%
sns.heatmap(data_Tamil_Nadu.corr(),cmap='RdBu')
plt.show()

# %%
sns.heatmap(data_Tamil_Nadu.corr(),center=0)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.heatmap(data_Tamil_Nadu.corr(),cmap='RdBu',annot=True)
plt.show()

# %% [markdown]
# # DISTPLOT

# %%
sns.distplot(data_Tamil_Nadu.TOTAL)
plt.show()
# Out:
# C:\Users\hp\Documents\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # DISPLOT

# %%
sns.displot(data_Tamil_Nadu.TOTAL)
plt.show()

# %%
sns.set_style('whitegrid')
sns.distplot(data_Tamil_Nadu.TOTAL,color='g')
plt.show()
# Out:
# C:\Users\hp\Documents\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_Tamil_Nadu.TOTAL,hist=False)
plt.show()
# Out:
# C:\Users\hp\Documents\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
