# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
d=pd.read_csv(r'C:\Users\hp\Downloads\archive (22)\Real estate.csv')

# %%
d
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
d1=d.rename(columns={"X1 transaction date":"Transaction_date","X2 house age":"House_age","X3 distance to the nearest MRT station":"distance to the nearest MRT station","X4 number of convenience stores":"number of convenience stores","X5 latitude":"latitude","X6 longitude":"longitude","Y house price of unit area":"house price of unit area"})

# %%
d1
# Out:
#       No  Transaction_date  House_age  distance to the nearest MRT station  \
# 0      1          2012.917       32.0                             84.87882
# 1      2          2012.917       19.5                            306.59470
# 2      3          2013.583       13.3                            561.98450
# 3      4          2013.500       13.3                            561.98450
# 4      5          2012.833        5.0                            390.56840
# ..   ...               ...        ...                                  ...
# 409  410          2013.000       13.7                           4082.01500
# 410  411          2012.667        5.6                             90.45606
# 411  412          2013.250       18.8                            390.96960
# 412  413          2013.000        8.1                            104.81010
# 413  414          2013.500        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude  \
# ...

# %%
d1.drop("No",axis=1,inplace=True)

# %%
d1
# Out:
#      Transaction_date  House_age  distance to the nearest MRT station  \
# 0            2012.917       32.0                             84.87882
# 1            2012.917       19.5                            306.59470
# 2            2013.583       13.3                            561.98450
# 3            2013.500       13.3                            561.98450
# 4            2012.833        5.0                            390.56840
# ..                ...        ...                                  ...
# 409          2013.000       13.7                           4082.01500
# 410          2012.667        5.6                             90.45606
# 411          2013.250       18.8                            390.96960
# 412          2013.000        8.1                            104.81010
# 413          2013.500        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude  \
# 0                              10  24.98298  121.54024
# ...

# %%
x=d1[['House_age','distance to the nearest MRT station','number of convenience stores','latitude','longitude']]
y=d1['house price of unit area']

# %%
x
# Out:
#      House_age  distance to the nearest MRT station  \
# 0         32.0                             84.87882
# 1         19.5                            306.59470
# 2         13.3                            561.98450
# 3         13.3                            561.98450
# 4          5.0                            390.56840
# ..         ...                                  ...
# 409       13.7                           4082.01500
# 410        5.6                             90.45606
# 411       18.8                            390.96960
# 412        8.1                            104.81010
# 413        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude
# 0                              10  24.98298  121.54024
# 1                               9  24.98034  121.53951
# 2                               5  24.98746  121.54391
# 3                               5  24.98746  121.54391
# 4                               5  24.97937  121.54245
# ...

# %%
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: house price of unit area, Length: 414, dtype: float64

# %%
print(x[:5])
# Out:
#    House_age  distance to the nearest MRT station  \
# 0       32.0                             84.87882
# 1       19.5                            306.59470
# 2       13.3                            561.98450
# 3       13.3                            561.98450
# 4        5.0                            390.56840
#
#    number of convenience stores  latitude  longitude
# 0                            10  24.98298  121.54024
# 1                             9  24.98034  121.53951
# 2                             5  24.98746  121.54391
# 3                             5  24.98746  121.54391
# 4                             5  24.97937  121.54245

# %%
print(x.shape)
# Out:
# (414, 5)

# %%
print(y[:5])
# Out:
# 0    37.9
# 1    42.2
# 2    47.3
# 3    54.8
# 4    43.1
# Name: house price of unit area, dtype: float64

# %%
print(y.shape)
# Out:
# (414,)

# %% [markdown]
# # PERFORM THE SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(np.mean(x_train))
print(np.mean(x_test))
print(np.mean(y_train))
print(np.mean(y_test))
# Out:
# House_age                                17.813595
# distance to the nearest MRT station    1052.998068
# number of convenience stores              4.205438
# latitude                                 24.969453
# longitude                               121.534048
# dtype: float64
# House_age                                17.309639
# distance to the nearest MRT station    1207.064031
# number of convenience stores              3.650602
# latitude                                 24.967345
# longitude                               121.530620
# dtype: float64
# 38.71299093655587
# 35.0578313253012

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()
l.fit(x_train,y_train)
print(l)
# Out:
# LinearRegression()

# %%
print("train test complete")
# Out:
# train test complete

# %%
y_pred=l.predict(x_test)

# %%
y_pred
# Out:
# array([33.07996225, 47.80869225, 22.11373816, 15.13096266, 44.6259416 ,
#        33.34343735, 31.19940423, 44.33327931, 39.97905651, 12.34608693,
#        13.8395669 , 39.23834498, 30.78835143, 45.73299058, 52.39244171,
#        34.0245196 , 44.6259416 , 43.13136871, 31.475026  , 46.30046212,
#        52.58815104, 29.97317982, 40.69807579, 48.86155195, 46.10788025,
#        28.72708906, 34.00302145, 45.51555296, 47.95300422, 14.53618299,
#        35.830845  , 35.24661163, 40.78115048, 45.61532743, 48.63792301,
#        14.1309192 , 41.07859656, 40.65344242, 38.5988199 , 15.05613181,
#        41.92880337, 25.42152773, 52.21783639, 34.88185988, 33.64942531,
#        39.47780571, 32.82670042, 41.10007362, 44.07963274, 34.27966577,
#        14.15586281, 43.05867842, 48.10381014, 15.2844915 , 51.29462089,
#        43.87893238, 44.6259416 , 39.2943165 , 40.7370706 , 42.33569508,
#        25.39313138, 41.71660439, 33.97016178, 14.1309192 , 40.50311433,
# ...

# %%
df=pd.DataFrame({'Actual':y_test,'Prediction':y_pred})

# %%
df
# Out:
#      Actual  Prediction
# 388    27.3   33.079962
# 102    54.4   47.808692
# 187    22.0   22.113738
# 162    11.6   15.130963
# 90     45.4   44.625942
# ..      ...         ...
# 322    33.1   41.626092
# 119    59.6   46.125857
# 245    40.8   44.362550
# 146    52.2   43.018887
# 360    47.1   48.926995
#
# [83 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error 5.3801551442702245

# %% [markdown]
# # DATA VISUALIZATION

# %%
df1=df.head(25)
df1.plot(kind='bar',figsize=(18,9))
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.regplot(x=y_test,y=y_pred)
plt.title("HOUSE PRICE PER UNIT AREA")
plt.show()
