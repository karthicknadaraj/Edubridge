# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
d=pd.read_csv(r'D:\DA\USA_Housing.csv')

# %%
d
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# # TO KNOW THE SHAPE AND SIZE

# %%
d.shape
# Out:
# (5000, 7)

# %%
d.size
# Out:
# 35000

# %% [markdown]
# # TO PRINT TOP 5 ROWS

# %%
d.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# # TO PRINT BOTTOM 5 ROWS

# %%
d.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %% [markdown]
# # DROP A COLUMN

# %%
d.drop('Address',axis=1,inplace=True)

# %%
d
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %% [markdown]
# # RENAME THE COLUMN NAMES

# %%
d=d.rename(columns={'Avg. Area Income':'Area Income','Avg. Area House Age':'House Age','Avg. Area Number of Rooms':'No of Rooms','Avg. Area Number of Bedrooms':'No of Bedrooms'})

# %% [markdown]
# # COLUMNS NAMES

# %%
d.columns
# Out:
# Index(['Area Income', 'House Age', 'No of Rooms', 'No of Bedrooms',
#        'Area Population', 'Price'],
#       dtype='object')

# %% [markdown]
# # TO PRINT RANDOM DATA

# %%
d.sample(6)
# Out:
#        Area Income  House Age  No of Rooms  No of Bedrooms  Area Population  \
# 1556  60871.603781   6.029590     7.282537            6.20     38111.353016
# 4603  85658.329275   6.569036     5.567667            2.04     35204.975697
# 4406  88850.476021   4.783567     6.159183            2.38     26565.334334
# 2664  65885.135759   7.652591     6.196093            4.02     34100.916771
# 2950  80077.930502   5.739522     7.437009            4.50     30774.394305
# 4732  55698.464800   5.185346     7.356115            3.10     42235.063823
#
#              Price
# 1556  1.427843e+06
# 4603  1.545962e+06
# 4406  1.205212e+06
# 2664  1.440737e+06
# 2950  1.603343e+06
# 4732  7.624022e+05

# %% [markdown]
# # TO CHECK THE DATATYPES

# %%
d.dtypes
# Out:
# Area Income        float64
# House Age          float64
# No of Rooms        float64
# No of Bedrooms     float64
# Area Population    float64
# Price              float64
# dtype: object

# %% [markdown]
# # TO PRINT THE INFO

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area Income      5000 non-null   float64
#  1   House Age        5000 non-null   float64
#  2   No of Rooms      5000 non-null   float64
#  3   No of Bedrooms   5000 non-null   float64
#  4   Area Population  5000 non-null   float64
#  5   Price            5000 non-null   float64
# dtypes: float64(6)
# memory usage: 234.5 KB

# %% [markdown]
# # TO PRINT THE NO OF DIMENSIONS

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# # TO CHECK WHETHER THE DATA IS EMPTY OR NOT

# %%
d.empty
# Out:
# False

# %% [markdown]
# # TO CHECK NULL VALUES

# %%
d.isnull().sum()
# Out:
# Area Income        0
# House Age          0
# No of Rooms        0
# No of Bedrooms     0
# Area Population    0
# Price              0
# dtype: int64

# %% [markdown]
# # TO PRINT STATISTICAL INFORMATION

# %%
d.describe()
# Out:
#          Area Income    House Age  No of Rooms  No of Bedrooms  \
# count    5000.000000  5000.000000  5000.000000     5000.000000
# mean    68583.108984     5.977222     6.987792        3.981330
# std     10657.991214     0.991456     1.005833        1.234137
# min     17796.631190     2.644304     3.236194        2.000000
# 25%     61480.562388     5.322283     6.299250        3.140000
# 50%     68804.286404     5.970429     7.002902        4.050000
# 75%     75783.338666     6.650808     7.665871        4.490000
# max    107701.748378     9.519088    10.759588        6.500000
#
#        Area Population         Price
# count      5000.000000  5.000000e+03
# mean      36163.516039  1.232073e+06
# std        9925.650114  3.531176e+05
# min         172.610686  1.593866e+04
# 25%       29403.928702  9.975771e+05
# 50%       36199.406689  1.232669e+06
# 75%       42861.290769  1.471210e+06
# max       69621.713378  2.469066e+06

# %%
d.describe(include='all')
# Out:
#          Area Income    House Age  No of Rooms  No of Bedrooms  \
# count    5000.000000  5000.000000  5000.000000     5000.000000
# mean    68583.108984     5.977222     6.987792        3.981330
# std     10657.991214     0.991456     1.005833        1.234137
# min     17796.631190     2.644304     3.236194        2.000000
# 25%     61480.562388     5.322283     6.299250        3.140000
# 50%     68804.286404     5.970429     7.002902        4.050000
# 75%     75783.338666     6.650808     7.665871        4.490000
# max    107701.748378     9.519088    10.759588        6.500000
#
#        Area Population         Price
# count      5000.000000  5.000000e+03
# mean      36163.516039  1.232073e+06
# std        9925.650114  3.531176e+05
# min         172.610686  1.593866e+04
# 25%       29403.928702  9.975771e+05
# 50%       36199.406689  1.232669e+06
# 75%       42861.290769  1.471210e+06
# max       69621.713378  2.469066e+06

# %% [markdown]
# # TO CHECK THE CORRELATION OF DATA

# %%
d.corr()
# Out:
#                  Area Income  House Age  No of Rooms  No of Bedrooms  \
# Area Income         1.000000  -0.002007    -0.011032        0.019788
# House Age          -0.002007   1.000000    -0.009428        0.006149
# No of Rooms        -0.011032  -0.009428     1.000000        0.462695
# No of Bedrooms      0.019788   0.006149     0.462695        1.000000
# Area Population    -0.016234  -0.018743     0.002040       -0.022168
# Price               0.639734   0.452543     0.335664        0.171071
#
#                  Area Population     Price
# Area Income            -0.016234  0.639734
# House Age              -0.018743  0.452543
# No of Rooms             0.002040  0.335664
# No of Bedrooms         -0.022168  0.171071
# Area Population         1.000000  0.408556
# Price                   0.408556  1.000000

# %% [markdown]
# # HEAT MAP

# %%
plt.figure(figsize=(14,7))
sns.heatmap(d.corr(),annot=True,center=0,linewidth=0.5,cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Here the Area Income and Price are correlated than others.

# %% [markdown]
# # SORTING THE VALUES OF HOUSE PRICE

# %%
hprice=d.sort_values('Price',ascending=False)

# %%
hprice
# Out:
#         Area Income  House Age  No of Rooms  No of Bedrooms  Area Population  \
# 465    90592.469609   7.700132     9.708803            5.19     37223.876167
# 2719  101599.670580   7.798746     7.480512            6.39     37523.864670
# 693   107701.748378   7.143522     8.518608            3.29     37619.439929
# 924    83814.101156   8.571797     7.392164            3.39     51538.056796
# 1248   94733.971275   7.885829     7.162373            5.41     46314.690046
# ...             ...        ...          ...             ...              ...
# 1661   48735.924512   5.543730     6.091906            2.43     19682.347295
# 1459   35963.330809   3.438547     8.264122            3.28     24435.777302
# 1799   60167.672607   4.590613     3.950973            4.06     16811.303292
# 1271   37971.207566   4.291224     5.807510            3.24     33267.767728
# 3212   47320.657205   3.558054     7.006987            3.16     15776.618595
#
#              Price
# 465   2.469066e+06
# ...

# %% [markdown]
# # HIGHEST AND LOWEST VALUES OF HOUSE PRICE

# %%
hprice['Price'].iloc[0]
# Out:
# 2469065.5941747027

# %%
hprice['Price'].iloc[-1]
# Out:
# 15938.657923287848

# %% [markdown]
# # COUNT THE NO OF BEDROOMS

# %%
d['No of Bedrooms'].value_counts()
# Out:
# 4.38    46
# 3.17    41
# 3.40    40
# 3.16    39
# 4.41    38
#         ..
# 6.17     7
# 5.42     6
# 6.01     6
# 6.02     6
# 6.42     5
# Name: No of Bedrooms, Length: 255, dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.scatterplot(x='No of Bedrooms',y='Price',color='r',data=d)
plt.show()

# %% [markdown]
# # PAIRPLOT

# %%
sns.pairplot(d)
plt.show()

# %% [markdown]
# # KDE PLOT

# %%
sns.kdeplot(d['Price'])
plt.show()

# %% [markdown]
# # REGRESSION PLOT

# %%
sns.regplot(x=d['House Age'],y=d['Price'],color='orange')
plt.show()

# %% [markdown]
# # DEFINE X AND Y

# %%
d.columns
# Out:
# Index(['Area Income', 'House Age', 'No of Rooms', 'No of Bedrooms',
#        'Area Population', 'Price'],
#       dtype='object')

# %%
x=d[['Area Income','House Age','No of Rooms','No of Bedrooms','Area Population']]
y=d['Price']

# %%
x
# Out:
#        Area Income  House Age  No of Rooms  No of Bedrooms  Area Population
# 0     79545.458574   5.682861     7.009188            4.09     23086.800503
# 1     79248.642455   6.002900     6.730821            3.09     40173.072174
# 2     61287.067179   5.865890     8.512727            5.13     36882.159400
# 3     63345.240046   7.188236     5.586729            3.26     34310.242831
# 4     59982.197226   5.040555     7.839388            4.23     26354.109472
# ...            ...        ...          ...             ...              ...
# 4995  60567.944140   7.830362     6.137356            3.46     22837.361035
# 4996  78491.275435   6.999135     6.576763            4.02     25616.115489
# 4997  63390.686886   7.250591     4.805081            2.13     33266.145490
# 4998  68001.331235   5.534388     7.130144            5.44     42625.620156
# 4999  65510.581804   5.992305     6.792336            4.07     46501.283803
#
# [5000 rows x 5 columns]

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %% [markdown]
# # SPLIT THE DATA IN TRAINING AND TESTING THE DATA

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=0)

# %%
print(x_train.shape)
# Out:
# (4500, 5)

# %%
print(y_train.shape)
# Out:
# (4500,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (500, 5)
# (500,)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()
l.fit(x_train,y_train)
print("train test complete")
# Out:
# train test complete

# %% [markdown]
# # PREDICTING THE TEST RESULT

# %%
y_pred=l.predict(x_test)
y_pred
# Out:
# array([ 971904.48265902,  955193.77148437,  908142.23373505,
#         494847.17536795,  718960.75458679, 1050579.68515785,
#         713626.33559088,  787349.92266849, 1803188.92708472,
#        1537949.2539071 ,  743899.82250445, 1146155.54047152,
#        2119763.66839869,  974545.30870687, 1152090.74192607,
#         875847.41046669, 1105260.87630919,  802536.96518347,
#        1204769.91500534, 1408245.02556246, 1140726.0522168 ,
#        1063463.58374101, 1436185.66931829, 1176072.76463879,
#        1296959.01216594, 1120962.11647915, 1118447.57095609,
#        1372302.61675448, 1588406.66919781, 1194372.04134232,
#        1561643.42776492, 2006204.66033001,  892162.40800438,
#        1325624.68398276, 1184310.88168948,  750033.04076708,
#        1083100.10655455, 1578336.67608127, 1260126.2073419 ,
#        1334051.32046684, 1595668.16940196,  962310.58467376,
#        1219803.18715413, 1116022.52553234, 1035208.37060975,
# ...

# %%
l.predict([[79545.45857,5.682861,7.009188,4.09,23086.80050]])
# Out:
# array([1223688.79654707])

# %%
d1=pd.DataFrame({'Actual':y_test,'Predict':y_pred})
d1
# Out:
#             Actual       Predict
# 398   8.942511e+05  9.719045e+05
# 3833  9.329794e+05  9.551938e+05
# 4836  9.207479e+05  9.081422e+05
# 4572  6.918549e+05  4.948472e+05
# 636   7.327332e+05  7.189608e+05
# ...            ...           ...
# 1928  1.100152e+06  1.295405e+06
# 4366  1.174779e+06  1.276332e+06
# 3550  1.388596e+06  1.427426e+06
# 2189  1.241699e+06  1.163525e+06
# 3480  9.839943e+05  9.713402e+05
#
# [500 rows x 2 columns]

# %% [markdown]
# # EVALUATING THE MODEL

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.921368085020744

# %% [markdown]
# The value 0.9 to 1 so it is linear

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 81188.89575951797

# %% [markdown]
# # SCATTERED PLOT OF ACTUAL AND PREDICTED

# %%
plt.scatter(y_test,y_pred,color='r')
plt.title('Actual vs Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.regplot(x=y_test,y=y_pred,color="green")
plt.title("Regressionplot",size=15)
plt.xlabel("Actual value",size=12)
plt.ylabel(" Predicted value",size=12)
plt.show()

# %% [markdown]
# TO PREDICT THE PRICE OF HOUSES MORE ACCURATELY USING DIFFERENT VARIABLES
